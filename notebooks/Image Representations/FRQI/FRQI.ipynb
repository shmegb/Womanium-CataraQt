# %% [markdown]
# # Flexible representation for quantum images (FRQI)
#
# Flexible representation for quantum images (**FRQI**)is an image representation in the form of a standardized state on a quantum computer. With **FRQI**s, color information is encoded as a normalized state which is then used to represent images on quantum computers.The FRQI compiles and converts color information and position information of image into a quantum state according to the method of classical image representation [1] The goal of the Flexible Representation of Quantum Images (FRQI) is to provide a quantum representation of images that allows an efficient encoding of the classical data into a quantum state and the  subsequent use of operators for image processing operations.
#
# The FRQI is capable of capturing image colours and their corresponding positions in a quantum state, and a quantum circuit using Hadamard gates and controlled rotation gates is suggested for the transform.
#
# ## The FRQI State
#
# The quantum state representing the image is:

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## Building the FRQI State:
#
# From an initialized state **|0⟩⊗2n+1** to the FRQI state is in full superposition, except for the last qubit which encoded the colour. **H⊗2n** being the tensor product of **2n** Hadamard operations, intermediate state is:

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ## Implementation
#
# all angles **θi** equal to **0** means that all the pixels are black, if all **θi** values are equal to **π/2** then all the pixels are white, and so on.
#
# **θi=π/2**, all pixels at maximum intensity
#
# The code will use the qiskit SDK from IBM.

# %%
pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\sumitha valsalam\anaconda3\lib\site-packages (0.43.0)
# Requirement already satisfied: qiskit-terra==0.24.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit) (0.24.0)
# Requirement already satisfied: qiskit-aer==0.12.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit) (0.12.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit) (0.20.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-aer==0.12.0->qiskit) (1.10.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-aer==0.12.0->qiskit) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.26.14)
# Requirement already satisfied: requests>=2.19 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.28.1)
# Requirement already satisfied: websockets>=10.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (11.0.3)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.5.2)
# Requirement already satisfied: requests-ntlm<=1.1.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.1.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit) (0.3.6)
# Requirement already satisfied: rustworkx>=0.12.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit) (0.12.1)
# Requirement already satisfied: psutil>=5 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit) (5.9.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit) (5.1.0)
# Requirement already satisfied: ply>=3.10 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit) (3.11)
# Requirement already satisfied: six>=1.5 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (3.4)
# Requirement already satisfied: cryptography>=1.3 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (39.0.1)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.24.0->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.24.0->qiskit) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\sumitha valsalam\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import the modules and tools needed for the work

# %%
import numpy as np
from qiskit import *
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from qiskit.providers.aer import QasmSimulator

# %% [markdown]
# ## FRQI Quantum Circuit
# In the implementation of the FRQI we could simplify the process by dividing it in just 3 parts.
#
# 1. The superposition of the pixel position qubits.
# 2. The use of X-gates to change the pixel position qubits.
# 3. The application of the rotational gates.
#
# ### Superposition of qubits
#
# Applying the hadamard gate in all the qubits:

# %%
pi = 3.14
theta1 = 0
theta2 = pi/2 # all pixels black
qc = QuantumCircuit(3)

qc.h(0)
qc.h(1)

qc.barrier()

# %% [markdown]
# ### Change of pixels
# The implementation of the FRQI needs to implement a ![q3.png](attachment:q3.png) gate for al the pixels in the image.
#
# #### Application of Gates

# %%
#Pixel 1

qc.cry(theta1,0,2)
qc.cx(0,1)
qc.cry(-theta1,1,2)
qc.cx(0,1)
qc.cry(theta1,1,2)

qc.barrier()

#Pixel 2

qc.x(1)
qc.cry(theta2,0,2)
qc.cx(0,1)
qc.cry(-theta2,1,2)
qc.cx(0,1)
qc.cry(theta2,1,2)

qc.barrier()

qc.x(1)
qc.x(0)
qc.cry(theta1,0,2)
qc.cx(0,1)
qc.cry(-theta1,1,2)
qc.cx(0,1)
qc.cry(theta1,1,2)


qc.barrier()

qc.x(1)

qc.cry(theta2,0,2)
qc.cx(0,1)
qc.cry(-theta2,1,2)
qc.cx(0,1)
qc.cry(theta2,1,2)

qc.measure_all()

qc.draw(output='mpl')

# %%
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1024)

results = job.result()
plot_histogram(results.get_counts(qc))

# %% [markdown]
# ### Reference:
#
# [1] Su, J., Guo, X., Liu, C., & Li, L. (Year). A New Trend of Quantum Image Representations. Journal Name, Volume(Issue), Page numbers. DOI: 10.1109/ACCESS.2020.3039996
#
# [2] Z. Boreiri, A. N. Azad and N. Majd, "Optimized Quantum Circuits in Quantum Image Processing Using Qiskit," 2022 International Conference on Machine Vision and Image Processing (MVIP), Ahvaz, Iran, Islamic Republic of, 2022, pp. 1-7, doi: 10.1109/MVIP53647.2022.9738550.
